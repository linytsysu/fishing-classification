# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_path = '../data/hy_round1_train_20200102'
test_path = '../data/hy_round1_testB_20200221'

train_df_list = []
for file_name in os.listdir(train_path):
    df = pd.read_csv(os.path.join(train_path, file_name))
    train_df_list.append(df)
    
test_df_list = []
for file_name in os.listdir(test_path):
    df = pd.read_csv(os.path.join(test_path, file_name))
    test_df_list.append(df)

train_df = pd.concat(train_df_list)
test_df = pd.concat(test_df_list)

train_df['time'] = pd.to_datetime(train_df['time'], format='%m%d %H:%M:%S')
test_df['time'] = pd.to_datetime(test_df['time'], format='%m%d %H:%M:%S')

all_df = pd.concat([train_df, test_df], sort=False)

# %%
from datetime import timedelta

data_list = []
for ship_id, group in all_df.groupby('渔船ID'):
    type_ = group['type'].values[0]
    group = group.sort_values(by=['time'])

    x = group['x'].values
    y = group['y'].values
    time_ = group['time'].values

    data_list.append([])
    time_list = []
    id_list = []
    dist_list = []
    speed_list = []
    for i in range(len(x) - 2):
        if i == 0:
            continue
        a = np.sqrt((x[i-1] - x[i]) ** 2 + (y[i-1] - y[i]) ** 2)
        during = (time_[i] - time_[i-1]) / np.timedelta64(1, 'h')

        dist_list.append(a)
        speed_list.append(a / during)
        id_list.append(int(ship_id))
        time_list.append(time_[i])

    dist_list = pd.Series(dist_list).values
    speed_list = pd.Series(speed_list).values

    data_list[-1].append(id_list)
    data_list[-1].append(time_list)
    data_list[-1].append(dist_list)
    data_list[-1].append(speed_list)

# %%
df_list = []
for i in range(len(data_list)):
    df = pd.DataFrame(np.array(data_list[i]).T, columns=['id', 'time', 'dist', 'speed'])
    df_list.append(df)
all_df_new = pd.concat(df_list)

# %%
all_df_new = all_df_new.fillna(-1)

# %%
from tsfresh import extract_features
extracted_df = extract_features(all_df_new, column_id='id', column_sort='time')
# Out:
# Feature Extraction: 100%|██████████| 30/30 [32:52<00:00, 65.75s/it]

# %%
y = []
for name, group in all_df.groupby('渔船ID'):
    y.append(group.iloc[0]['type'])

y_train = y[:7000]
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y_train = le.fit_transform(y_train)

# %%
from feature_selector import FeatureSelector

# %%
train_df = extracted_df.iloc[:7000]
test_df = extracted_df.iloc[7000:]

# %%
train_df.to_csv('train_temp.csv', index=False)
test_df.to_csv('test_temp.csv', index=False)

# %%
train_df = pd.read_csv('train_temp.csv')
test_df = pd.read_csv('test_temp.csv')

# %%
fs = FeatureSelector(data=train_df, labels=y_train)

# %%
fs.identify_missing(missing_threshold=0.6)
# Out:
# 10 features with greater than 0.60 missing values.

# %%
fs.identify_single_unique()
# Out:
# 37 features with a single unique value.

# %%
fs.identify_collinear(correlation_threshold=0.95)
# Out:
# 566 features with a correlation magnitude greater than 0.95.

# %%
fs.identify_zero_importance(task='classification', eval_metric='multi_logloss', 
                            n_iterations=10, early_stopping=True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [152]	valid_0's multi_logloss: 0.518897
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [182]	valid_0's multi_logloss: 0.524332
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [115]	valid_0's multi_logloss: 0.562417
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [161]	valid_0's multi_logloss: 0.527295
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [145]	valid_0's multi_logloss: 0.521978
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [148]	valid_0's multi_logloss: 0.548216
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [163]	valid_0's multi_logloss: 0.533949
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [137]	valid_0's multi_logloss: 0.5199
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [127]	valid_0's multi_logloss: 0.532555
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [179]	valid_0's multi_logloss: 0.486778
#
# 107 features with zero importance after one-hot encoding.

# %%
fs.identify_low_importance(cumulative_importance=0.99)
# Out:
# 1294 features required for cumulative importance of 0.99 after one hot encoding.
# 214 features do not contribute to cumulative importance of 0.99.

# %%
fs.ops
# Out:
# {'missing': ['dist__friedrich_coefficients__m_3__r_30__coeff_0',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_1',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_2',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_3',
#   'dist__max_langevin_fixed_point__m_3__r_30',
#   'speed__friedrich_coefficients__m_3__r_30__coeff_0',
#   'speed__friedrich_coefficients__m_3__r_30__coeff_1',
#   'speed__friedrich_coefficients__m_3__r_30__coeff_2',
#   'speed__friedrich_coefficients__m_3__r_30__coeff_3',
#   'speed__max_langevin_fixed_point__m_3__r_30'],
#  'single_unique': ['dist__fft_coefficient__coeff_0__attr_"angle"',
#   'dist__fft_coefficient__coeff_0__attr_"imag"',
#   'dist__large_standard_deviation__r_0.5',
#   'dist__large_standard_deviation__r_0.55',
#   'dist__large_standard_deviation__r_0.6000000000000001',
#   'dist__large_standard_deviation__r_0.65',
#   'dist__large_standard_deviation__r_0.7000000000000001',
#   'dist__large_standard_deviation__r_0.75',
#   'dist__large_standard_deviation__r_0.8',
#   'dist__large_standard_deviation__r_0.8500000000000001',
#   'dist__large_standard_deviation__r_0.9',
#   'dist__large_standard_deviation__r_0.9500000000000001',
#   'dist__number_crossing_m__m_-1',
#   'dist__partial_autocorrelation__lag_0',
#   'dist__range_count__max_0__min_1000000000000.0',
#   'dist__symmetry_looking__r_0.0',
#   'dist__value_count__value_-1',
#   'dist__value_count__value_1',
#   'speed__fft_coefficient__coeff_0__attr_"angle"',
#   'speed__fft_coefficient__coeff_0__attr_"imag"',
#   'speed__large_standard_deviation__r_0.45',
#   'speed__large_standard_deviation__r_0.5',
#   'speed__large_standard_deviation__r_0.55',
#   'speed__large_standard_deviation__r_0.6000000000000001',
#   'speed__large_standard_deviation__r_0.65',
#   'speed__large_standard_deviation__r_0.7000000000000001',
#   'speed__large_standard_deviation__r_0.75',
#   'speed__large_standard_deviation__r_0.8',
#   'speed__large_standard_deviation__r_0.8500000000000001',
#   'speed__large_standard_deviation__r_0.9',
#   'speed__large_standard_deviation__r_0.9500000000000001',
#   'speed__number_crossing_m__m_-1',
#   'speed__partial_autocorrelation__lag_0',
#   'speed__range_count__max_0__min_1000000000000.0',
#   'speed__symmetry_looking__r_0.0',
#   'speed__value_count__value_-1',
#   'speed__value_count__value_1'],
#  'collinear': ['dist__agg_autocorrelation__f_agg_"median"__maxlag_40',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"rvalue"',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"rvalue"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"rvalue"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr"',
#   'dist__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"rvalue"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"stderr"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"rvalue"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"stderr"',
#   'dist__approximate_entropy__m_2__r_0.5',
#   'dist__approximate_entropy__m_2__r_0.7',
#   'dist__approximate_entropy__m_2__r_0.9',
#   'dist__ar_coefficient__k_10__coeff_4',
#   'dist__autocorrelation__lag_3',
#   'dist__autocorrelation__lag_4',
#   'dist__autocorrelation__lag_5',
#   'dist__autocorrelation__lag_6',
#   'dist__autocorrelation__lag_7',
#   'dist__autocorrelation__lag_8',
#   'dist__autocorrelation__lag_9',
#   'dist__c3__lag_1',
#   'dist__c3__lag_2',
#   'dist__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2',
#   'dist__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4',
#   'dist__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6',
#   'dist__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.6',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.6',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_10',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20',
#   'dist__fft_coefficient__coeff_0__attr_"real"',
#   'dist__fft_coefficient__coeff_10__attr_"abs"',
#   'dist__fft_coefficient__coeff_11__attr_"abs"',
#   'dist__fft_coefficient__coeff_12__attr_"abs"',
#   'dist__fft_coefficient__coeff_13__attr_"abs"',
#   'dist__fft_coefficient__coeff_14__attr_"abs"',
#   'dist__fft_coefficient__coeff_15__attr_"abs"',
#   'dist__fft_coefficient__coeff_16__attr_"abs"',
#   'dist__fft_coefficient__coeff_17__attr_"abs"',
#   'dist__fft_coefficient__coeff_18__attr_"abs"',
#   'dist__fft_coefficient__coeff_19__attr_"abs"',
#   'dist__fft_coefficient__coeff_20__attr_"abs"',
#   'dist__fft_coefficient__coeff_21__attr_"abs"',
#   'dist__fft_coefficient__coeff_22__attr_"abs"',
#   'dist__fft_coefficient__coeff_23__attr_"abs"',
#   'dist__fft_coefficient__coeff_24__attr_"abs"',
#   'dist__fft_coefficient__coeff_25__attr_"abs"',
#   'dist__fft_coefficient__coeff_26__attr_"abs"',
#   'dist__fft_coefficient__coeff_27__attr_"abs"',
#   'dist__fft_coefficient__coeff_28__attr_"abs"',
#   'dist__fft_coefficient__coeff_29__attr_"abs"',
#   'dist__fft_coefficient__coeff_2__attr_"abs"',
#   'dist__fft_coefficient__coeff_30__attr_"abs"',
#   'dist__fft_coefficient__coeff_31__attr_"abs"',
#   'dist__fft_coefficient__coeff_32__attr_"abs"',
#   'dist__fft_coefficient__coeff_33__attr_"abs"',
#   'dist__fft_coefficient__coeff_34__attr_"abs"',
#   'dist__fft_coefficient__coeff_35__attr_"abs"',
#   'dist__fft_coefficient__coeff_36__attr_"abs"',
#   'dist__fft_coefficient__coeff_37__attr_"abs"',
#   'dist__fft_coefficient__coeff_38__attr_"abs"',
#   'dist__fft_coefficient__coeff_39__attr_"abs"',
#   'dist__fft_coefficient__coeff_3__attr_"abs"',
#   'dist__fft_coefficient__coeff_40__attr_"abs"',
#   'dist__fft_coefficient__coeff_41__attr_"abs"',
#   'dist__fft_coefficient__coeff_42__attr_"abs"',
#   'dist__fft_coefficient__coeff_43__attr_"abs"',
#   'dist__fft_coefficient__coeff_44__attr_"abs"',
#   'dist__fft_coefficient__coeff_45__attr_"abs"',
#   'dist__fft_coefficient__coeff_46__attr_"abs"',
#   'dist__fft_coefficient__coeff_47__attr_"abs"',
#   'dist__fft_coefficient__coeff_48__attr_"abs"',
#   'dist__fft_coefficient__coeff_49__attr_"abs"',
#   'dist__fft_coefficient__coeff_4__attr_"abs"',
#   'dist__fft_coefficient__coeff_50__attr_"abs"',
#   'dist__fft_coefficient__coeff_51__attr_"abs"',
#   'dist__fft_coefficient__coeff_52__attr_"abs"',
#   'dist__fft_coefficient__coeff_53__attr_"abs"',
#   'dist__fft_coefficient__coeff_54__attr_"abs"',
#   'dist__fft_coefficient__coeff_55__attr_"abs"',
#   'dist__fft_coefficient__coeff_56__attr_"abs"',
#   'dist__fft_coefficient__coeff_57__attr_"abs"',
#   'dist__fft_coefficient__coeff_58__attr_"abs"',
#   'dist__fft_coefficient__coeff_59__attr_"abs"',
#   'dist__fft_coefficient__coeff_5__attr_"abs"',
#   'dist__fft_coefficient__coeff_60__attr_"abs"',
#   'dist__fft_coefficient__coeff_61__attr_"abs"',
#   'dist__fft_coefficient__coeff_62__attr_"abs"',
#   'dist__fft_coefficient__coeff_63__attr_"abs"',
#   'dist__fft_coefficient__coeff_64__attr_"abs"',
#   'dist__fft_coefficient__coeff_65__attr_"abs"',
#   'dist__fft_coefficient__coeff_66__attr_"abs"',
#   'dist__fft_coefficient__coeff_67__attr_"abs"',
#   'dist__fft_coefficient__coeff_68__attr_"abs"',
#   'dist__fft_coefficient__coeff_69__attr_"abs"',
#   'dist__fft_coefficient__coeff_6__attr_"abs"',
#   'dist__fft_coefficient__coeff_70__attr_"abs"',
#   'dist__fft_coefficient__coeff_71__attr_"abs"',
#   'dist__fft_coefficient__coeff_72__attr_"abs"',
#   'dist__fft_coefficient__coeff_73__attr_"abs"',
#   'dist__fft_coefficient__coeff_74__attr_"abs"',
#   'dist__fft_coefficient__coeff_75__attr_"abs"',
#   'dist__fft_coefficient__coeff_76__attr_"abs"',
#   'dist__fft_coefficient__coeff_77__attr_"abs"',
#   'dist__fft_coefficient__coeff_78__attr_"abs"',
#   'dist__fft_coefficient__coeff_79__attr_"abs"',
#   'dist__fft_coefficient__coeff_7__attr_"abs"',
#   'dist__fft_coefficient__coeff_80__attr_"abs"',
#   'dist__fft_coefficient__coeff_81__attr_"abs"',
#   'dist__fft_coefficient__coeff_82__attr_"abs"',
#   'dist__fft_coefficient__coeff_83__attr_"abs"',
#   'dist__fft_coefficient__coeff_84__attr_"abs"',
#   'dist__fft_coefficient__coeff_85__attr_"abs"',
#   'dist__fft_coefficient__coeff_86__attr_"abs"',
#   'dist__fft_coefficient__coeff_87__attr_"abs"',
#   'dist__fft_coefficient__coeff_88__attr_"abs"',
#   'dist__fft_coefficient__coeff_89__attr_"abs"',
#   'dist__fft_coefficient__coeff_8__attr_"abs"',
#   'dist__fft_coefficient__coeff_90__attr_"abs"',
#   'dist__fft_coefficient__coeff_91__attr_"abs"',
#   'dist__fft_coefficient__coeff_92__attr_"abs"',
#   'dist__fft_coefficient__coeff_93__attr_"abs"',
#   'dist__fft_coefficient__coeff_94__attr_"abs"',
#   'dist__fft_coefficient__coeff_95__attr_"abs"',
#   'dist__fft_coefficient__coeff_96__attr_"abs"',
#   'dist__fft_coefficient__coeff_97__attr_"abs"',
#   'dist__fft_coefficient__coeff_98__attr_"abs"',
#   'dist__fft_coefficient__coeff_99__attr_"abs"',
#   'dist__fft_coefficient__coeff_9__attr_"abs"',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_0',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_3',
#   'dist__index_mass_quantile__q_0.7',
#   'dist__index_mass_quantile__q_0.8',
#   'dist__index_mass_quantile__q_0.9',
#   'dist__linear_trend__attr_"intercept"',
#   'dist__linear_trend__attr_"rvalue"',
#   'dist__linear_trend__attr_"slope"',
#   'dist__linear_trend__attr_"stderr"',
#   'dist__max_langevin_fixed_point__m_3__r_30',
#   'dist__maximum',
#   'dist__mean',
#   'dist__mean_abs_change',
#   'dist__mean_change',
#   'dist__mean_second_derivative_central',
#   'dist__number_crossing_m__m_1',
#   'dist__number_peaks__n_10',
#   'dist__number_peaks__n_3',
#   'dist__number_peaks__n_5',
#   'dist__partial_autocorrelation__lag_1',
#   'dist__range_count__max_1000000000000.0__min_0',
#   'dist__ratio_value_number_to_time_series_length',
#   'dist__spkt_welch_density__coeff_5',
#   'dist__spkt_welch_density__coeff_8',
#   'dist__standard_deviation',
#   'dist__sum_values',
#   'dist__symmetry_looking__r_0.30000000000000004',
#   'dist__symmetry_looking__r_0.35000000000000003',
#   'dist__symmetry_looking__r_0.4',
#   'dist__symmetry_looking__r_0.45',
#   'dist__symmetry_looking__r_0.5',
#   'dist__symmetry_looking__r_0.55',
#   'dist__symmetry_looking__r_0.6000000000000001',
#   'dist__symmetry_looking__r_0.65',
#   'dist__symmetry_looking__r_0.7000000000000001',
#   'dist__symmetry_looking__r_0.75',
#   'dist__symmetry_looking__r_0.8',
#   'dist__symmetry_looking__r_0.8500000000000001',
#   'dist__symmetry_looking__r_0.9',
#   'dist__symmetry_looking__r_0.9500000000000001',
#   'dist__time_reversal_asymmetry_statistic__lag_1',
#   'dist__time_reversal_asymmetry_statistic__lag_2',
#   'dist__time_reversal_asymmetry_statistic__lag_3',
#   'dist__value_count__value_0',
#   'dist__variance',
#   'dist__variance_larger_than_standard_deviation',
#   'speed__agg_autocorrelation__f_agg_"mean"__maxlag_40',
#   'speed__agg_autocorrelation__f_agg_"median"__maxlag_40',
#   'speed__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr"',
#   'speed__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"rvalue"',
#   'speed__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"stderr"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"rvalue"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"rvalue"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr"',
#   'speed__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"rvalue"',
#   'speed__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue"',
#   'speed__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"stderr"',
#   'speed__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"rvalue"',
#   'speed__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"slope"',
#   'speed__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"stderr"',
#   'speed__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"slope"',
#   'speed__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"stderr"',
#   'speed__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"slope"',
#   'speed__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"stderr"',
#   'speed__approximate_entropy__m_2__r_0.1',
#   'speed__approximate_entropy__m_2__r_0.5',
#   'speed__approximate_entropy__m_2__r_0.7',
#   'speed__approximate_entropy__m_2__r_0.9',
#   'speed__ar_coefficient__k_10__coeff_0',
#   'speed__ar_coefficient__k_10__coeff_4',
#   'speed__augmented_dickey_fuller__attr_"teststat"',
#   'speed__autocorrelation__lag_3',
#   'speed__autocorrelation__lag_4',
#   'speed__autocorrelation__lag_5',
#   'speed__autocorrelation__lag_6',
#   'speed__autocorrelation__lag_7',
#   'speed__autocorrelation__lag_8',
#   'speed__autocorrelation__lag_9',
#   'speed__c3__lag_1',
#   'speed__c3__lag_2',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.4',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.6',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#   'speed__cid_ce__normalize_False',
#   'speed__count_below_mean',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_5',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20',
#   'speed__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
#   'speed__energy_ratio_by_chunks__num_segments_10__segment_focus_1',
#   'speed__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#   'speed__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#   'speed__fft_aggregated__aggtype_"variance"',
#   'speed__fft_coefficient__coeff_0__attr_"real"',
#   'speed__fft_coefficient__coeff_10__attr_"abs"',
#   'speed__fft_coefficient__coeff_11__attr_"abs"',
#   'speed__fft_coefficient__coeff_12__attr_"abs"',
#   'speed__fft_coefficient__coeff_13__attr_"abs"',
#   'speed__fft_coefficient__coeff_14__attr_"abs"',
#   'speed__fft_coefficient__coeff_15__attr_"abs"',
#   'speed__fft_coefficient__coeff_16__attr_"abs"',
#   'speed__fft_coefficient__coeff_17__attr_"abs"',
#   'speed__fft_coefficient__coeff_18__attr_"abs"',
#   'speed__fft_coefficient__coeff_19__attr_"abs"',
#   'speed__fft_coefficient__coeff_1__attr_"abs"',
#   'speed__fft_coefficient__coeff_20__attr_"abs"',
#   'speed__fft_coefficient__coeff_21__attr_"abs"',
#   'speed__fft_coefficient__coeff_22__attr_"abs"',
#   'speed__fft_coefficient__coeff_23__attr_"abs"',
#   'speed__fft_coefficient__coeff_24__attr_"abs"',
#   'speed__fft_coefficient__coeff_25__attr_"abs"',
#   'speed__fft_coefficient__coeff_26__attr_"abs"',
#   'speed__fft_coefficient__coeff_27__attr_"abs"',
#   'speed__fft_coefficient__coeff_28__attr_"abs"',
#   'speed__fft_coefficient__coeff_29__attr_"abs"',
#   'speed__fft_coefficient__coeff_2__attr_"abs"',
#   'speed__fft_coefficient__coeff_30__attr_"abs"',
#   'speed__fft_coefficient__coeff_31__attr_"abs"',
#   'speed__fft_coefficient__coeff_32__attr_"abs"',
#   'speed__fft_coefficient__coeff_33__attr_"abs"',
#   'speed__fft_coefficient__coeff_34__attr_"abs"',
#   'speed__fft_coefficient__coeff_35__attr_"abs"',
#   'speed__fft_coefficient__coeff_36__attr_"abs"',
#   'speed__fft_coefficient__coeff_37__attr_"abs"',
#   'speed__fft_coefficient__coeff_38__attr_"abs"',
#   'speed__fft_coefficient__coeff_39__attr_"abs"',
#   'speed__fft_coefficient__coeff_3__attr_"abs"',
#   'speed__fft_coefficient__coeff_40__attr_"abs"',
#   'speed__fft_coefficient__coeff_41__attr_"abs"',
#   'speed__fft_coefficient__coeff_42__attr_"abs"',
#   'speed__fft_coefficient__coeff_43__attr_"abs"',
#   'speed__fft_coefficient__coeff_44__attr_"abs"',
#   'speed__fft_coefficient__coeff_45__attr_"abs"',
#   'speed__fft_coefficient__coeff_46__attr_"abs"',
#   'speed__fft_coefficient__coeff_47__attr_"abs"',
#   'speed__fft_coefficient__coeff_48__attr_"abs"',
#   'speed__fft_coefficient__coeff_49__attr_"abs"',
#   'speed__fft_coefficient__coeff_4__attr_"abs"',
#   'speed__fft_coefficient__coeff_50__attr_"abs"',
#   'speed__fft_coefficient__coeff_51__attr_"abs"',
#   'speed__fft_coefficient__coeff_52__attr_"abs"',
#   'speed__fft_coefficient__coeff_53__attr_"abs"',
#   'speed__fft_coefficient__coeff_54__attr_"abs"',
#   'speed__fft_coefficient__coeff_55__attr_"abs"',
#   'speed__fft_coefficient__coeff_56__attr_"abs"',
#   'speed__fft_coefficient__coeff_57__attr_"abs"',
#   'speed__fft_coefficient__coeff_58__attr_"abs"',
#   'speed__fft_coefficient__coeff_59__attr_"abs"',
#   'speed__fft_coefficient__coeff_5__attr_"abs"',
#   'speed__fft_coefficient__coeff_60__attr_"abs"',
#   'speed__fft_coefficient__coeff_61__attr_"abs"',
#   'speed__fft_coefficient__coeff_62__attr_"abs"',
#   'speed__fft_coefficient__coeff_63__attr_"abs"',
#   'speed__fft_coefficient__coeff_64__attr_"abs"',
#   'speed__fft_coefficient__coeff_65__attr_"abs"',
#   'speed__fft_coefficient__coeff_66__attr_"abs"',
#   'speed__fft_coefficient__coeff_67__attr_"abs"',
#   'speed__fft_coefficient__coeff_68__attr_"abs"',
#   'speed__fft_coefficient__coeff_69__attr_"abs"',
#   'speed__fft_coefficient__coeff_6__attr_"abs"',
#   'speed__fft_coefficient__coeff_70__attr_"abs"',
#   'speed__fft_coefficient__coeff_71__attr_"abs"',
#   'speed__fft_coefficient__coeff_72__attr_"abs"',
#   'speed__fft_coefficient__coeff_73__attr_"abs"',
#   'speed__fft_coefficient__coeff_74__attr_"abs"',
#   'speed__fft_coefficient__coeff_75__attr_"abs"',
#   'speed__fft_coefficient__coeff_76__attr_"abs"',
#   'speed__fft_coefficient__coeff_77__attr_"abs"',
#   'speed__fft_coefficient__coeff_78__attr_"abs"',
#   'speed__fft_coefficient__coeff_79__attr_"abs"',
#   'speed__fft_coefficient__coeff_7__attr_"abs"',
#   'speed__fft_coefficient__coeff_80__attr_"abs"',
#   'speed__fft_coefficient__coeff_81__attr_"abs"',
#   'speed__fft_coefficient__coeff_82__attr_"abs"',
#   'speed__fft_coefficient__coeff_83__attr_"abs"',
#   'speed__fft_coefficient__coeff_84__attr_"abs"',
#   'speed__fft_coefficient__coeff_85__attr_"abs"',
#   'speed__fft_coefficient__coeff_86__attr_"abs"',
#   'speed__fft_coefficient__coeff_87__attr_"abs"',
#   'speed__fft_coefficient__coeff_88__attr_"abs"',
#   'speed__fft_coefficient__coeff_89__attr_"abs"',
#   'speed__fft_coefficient__coeff_8__attr_"abs"',
#   'speed__fft_coefficient__coeff_90__attr_"abs"',
#   'speed__fft_coefficient__coeff_91__attr_"abs"',
#   'speed__fft_coefficient__coeff_92__attr_"abs"',
#   'speed__fft_coefficient__coeff_93__attr_"abs"',
#   'speed__fft_coefficient__coeff_94__attr_"abs"',
#   'speed__fft_coefficient__coeff_95__attr_"abs"',
#   'speed__fft_coefficient__coeff_96__attr_"abs"',
#   'speed__fft_coefficient__coeff_97__attr_"abs"',
#   'speed__fft_coefficient__coeff_98__attr_"abs"',
#   'speed__fft_coefficient__coeff_99__attr_"abs"',
#   'speed__fft_coefficient__coeff_9__attr_"abs"',
#   'speed__first_location_of_minimum',
#   'speed__has_duplicate_min',
#   'speed__index_mass_quantile__q_0.1',
#   'speed__index_mass_quantile__q_0.2',
#   'speed__index_mass_quantile__q_0.3',
#   'speed__index_mass_quantile__q_0.4',
#   'speed__index_mass_quantile__q_0.6',
#   'speed__index_mass_quantile__q_0.7',
#   'speed__index_mass_quantile__q_0.8',
#   'speed__index_mass_quantile__q_0.9',
#   'speed__large_standard_deviation__r_0.05',
#   'speed__last_location_of_minimum',
#   'speed__length',
#   'speed__linear_trend__attr_"intercept"',
#   'speed__linear_trend__attr_"rvalue"',
#   'speed__linear_trend__attr_"slope"',
#   'speed__linear_trend__attr_"stderr"',
#   'speed__longest_strike_above_mean',
#   'speed__longest_strike_below_mean',
#   'speed__max_langevin_fixed_point__m_3__r_30',
#   'speed__maximum',
#   'speed__mean_abs_change',
#   'speed__mean_change',
#   'speed__mean_second_derivative_central',
#   'speed__median',
#   'speed__number_crossing_m__m_0',
#   'speed__number_crossing_m__m_1',
#   'speed__number_cwt_peaks__n_1',
#   'speed__number_peaks__n_1',
#   'speed__number_peaks__n_3',
#   'speed__number_peaks__n_5',
#   'speed__partial_autocorrelation__lag_1',
#   'speed__partial_autocorrelation__lag_6',
#   'speed__percentage_of_reoccurring_values_to_all_values',
#   'speed__quantile__q_0.1',
#   'speed__quantile__q_0.2',
#   'speed__quantile__q_0.3',
#   'speed__quantile__q_0.4',
#   'speed__quantile__q_0.6',
#   'speed__range_count__max_1000000000000.0__min_0',
#   'speed__range_count__max_1__min_-1',
#   'speed__ratio_value_number_to_time_series_length',
#   'speed__spkt_welch_density__coeff_5',
#   'speed__spkt_welch_density__coeff_8',
#   'speed__standard_deviation',
#   'speed__sum_of_reoccurring_values',
#   'speed__sum_values',
#   'speed__symmetry_looking__r_0.30000000000000004',
#   'speed__symmetry_looking__r_0.35000000000000003',
#   'speed__symmetry_looking__r_0.4',
#   'speed__symmetry_looking__r_0.45',
#   'speed__symmetry_looking__r_0.5',
#   'speed__symmetry_looking__r_0.55',
#   'speed__symmetry_looking__r_0.6000000000000001',
#   'speed__symmetry_looking__r_0.65',
#   'speed__symmetry_looking__r_0.7000000000000001',
#   'speed__symmetry_looking__r_0.75',
#   'speed__symmetry_looking__r_0.8',
#   'speed__symmetry_looking__r_0.8500000000000001',
#   'speed__symmetry_looking__r_0.9',
#   'speed__symmetry_looking__r_0.9500000000000001',
#   'speed__time_reversal_asymmetry_statistic__lag_1',
#   'speed__value_count__value_0',
#   'speed__variance',
#   'speed__variance_larger_than_standard_deviation'],
#  'zero_importance': ['speed__fft_coefficient__coeff_0__attr_"real"',
#   'speed__symmetry_looking__r_0.8500000000000001',
#   'speed__symmetry_looking__r_0.9',
#   'speed__symmetry_looking__r_0.9500000000000001',
#   'speed__value_count__value_-1',
#   'speed__value_count__value_0',
#   'speed__value_count__value_1',
#   'speed__variance',
#   'speed__partial_autocorrelation__lag_0',
#   'dist__autocorrelation__lag_0',
#   'speed__symmetry_looking__r_0.8',
#   'speed__partial_autocorrelation__lag_1',
#   'speed__range_count__max_1__min_-1',
#   'speed__range_count__max_1000000000000.0__min_0',
#   'speed__range_count__max_0__min_1000000000000.0',
#   'speed__fft_coefficient__coeff_0__attr_"imag"',
#   'speed__sum_values',
#   'speed__symmetry_looking__r_0.0',
#   'speed__symmetry_looking__r_0.25',
#   'speed__symmetry_looking__r_0.30000000000000004',
#   'speed__symmetry_looking__r_0.35000000000000003',
#   'speed__symmetry_looking__r_0.4',
#   'speed__symmetry_looking__r_0.45',
#   'speed__symmetry_looking__r_0.5',
#   'speed__symmetry_looking__r_0.55',
#   'speed__symmetry_looking__r_0.6000000000000001',
#   'speed__symmetry_looking__r_0.65',
#   'speed__symmetry_looking__r_0.7000000000000001',
#   'speed__symmetry_looking__r_0.75',
#   'speed__fft_coefficient__coeff_0__attr_"angle"',
#   'dist__symmetry_looking__r_0.8500000000000001',
#   'speed__number_crossing_m__m_1',
#   'dist__large_standard_deviation__r_0.75',
#   'dist__number_crossing_m__m_1',
#   'dist__number_crossing_m__m_-1',
#   'dist__mean_abs_change',
#   'dist__large_standard_deviation__r_0.9500000000000001',
#   'dist__large_standard_deviation__r_0.9',
#   'dist__large_standard_deviation__r_0.8500000000000001',
#   'dist__large_standard_deviation__r_0.8',
#   'dist__large_standard_deviation__r_0.7000000000000001',
#   'speed__number_crossing_m__m_0',
#   'dist__large_standard_deviation__r_0.65',
#   'dist__large_standard_deviation__r_0.6000000000000001',
#   'dist__large_standard_deviation__r_0.55',
#   'dist__large_standard_deviation__r_0.5',
#   'dist__large_standard_deviation__r_0.45',
#   'dist__large_standard_deviation__r_0.4',
#   'dist__large_standard_deviation__r_0.35000000000000003',
#   'dist__partial_autocorrelation__lag_0',
#   'dist__partial_autocorrelation__lag_1',
#   'dist__range_count__max_0__min_1000000000000.0',
#   'dist__range_count__max_1000000000000.0__min_0',
#   'dist__symmetry_looking__r_0.75',
#   'dist__symmetry_looking__r_0.7000000000000001',
#   'dist__symmetry_looking__r_0.65',
#   'dist__symmetry_looking__r_0.6000000000000001',
#   'dist__symmetry_looking__r_0.55',
#   'dist__symmetry_looking__r_0.5',
#   'dist__symmetry_looking__r_0.45',
#   'dist__symmetry_looking__r_0.4',
#   'dist__symmetry_looking__r_0.35000000000000003',
#   'dist__symmetry_looking__r_0.30000000000000004',
#   'dist__symmetry_looking__r_0.25',
#   'dist__symmetry_looking__r_0.9',
#   'dist__symmetry_looking__r_0.2',
#   'dist__symmetry_looking__r_0.0',
#   'dist__sum_values',
#   'dist__large_standard_deviation__r_0.30000000000000004',
#   'dist__large_standard_deviation__r_0.15000000000000002',
#   'dist__large_standard_deviation__r_0.05',
#   'speed__large_standard_deviation__r_0.25',
#   'speed__large_standard_deviation__r_0.45',
#   'speed__large_standard_deviation__r_0.5',
#   'speed__large_standard_deviation__r_0.55',
#   'speed__large_standard_deviation__r_0.6000000000000001',
#   'speed__large_standard_deviation__r_0.65',
#   'speed__large_standard_deviation__r_0.7000000000000001',
#   'speed__large_standard_deviation__r_0.75',
#   'speed__large_standard_deviation__r_0.8',
#   'speed__large_standard_deviation__r_0.8500000000000001',
#   'speed__large_standard_deviation__r_0.9',
#   'speed__large_standard_deviation__r_0.9500000000000001',
#   'speed__length',
#   'speed__mean_abs_change',
#   'speed__minimum',
#   'speed__number_crossing_m__m_-1',
#   'speed__large_standard_deviation__r_0.4',
#   'speed__large_standard_deviation__r_0.15000000000000002',
#   'dist__has_duplicate_min',
#   'speed__large_standard_deviation__r_0.05',
#   'dist__has_duplicate',
#   'dist__symmetry_looking__r_0.9500000000000001',
#   'dist__value_count__value_-1',
#   'dist__value_count__value_0',
#   'dist__value_count__value_1',
#   'dist__variance',
#   'dist__variance_larger_than_standard_deviation',
#   'speed__autocorrelation__lag_0',
#   'dist__fft_coefficient__coeff_0__attr_"real"',
#   'dist__fft_coefficient__coeff_0__attr_"imag"',
#   'dist__fft_coefficient__coeff_0__attr_"angle"',
#   'dist__symmetry_looking__r_0.8',
#   'speed__has_duplicate',
#   'speed__has_duplicate_max',
#   'speed__has_duplicate_min',
#   'speed__variance_larger_than_standard_deviation'],
#  'low_importance': ['dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_5',
#   'speed__cid_ce__normalize_False',
#   'speed__symmetry_looking__r_0.1',
#   'speed__fft_coefficient__coeff_21__attr_"abs"',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20',
#   'speed__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_20',
#   'dist__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#   'speed__fft_coefficient__coeff_66__attr_"abs"',
#   'speed__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"',
#   'speed__friedrich_coefficients__m_3__r_30__coeff_1',
#   'dist__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4',
#   'dist__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"intercept"',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#   'dist__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr"',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_3',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr"',
#   'speed__friedrich_coefficients__m_3__r_30__coeff_3',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_20',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_20',
#   'speed__linear_trend__attr_"stderr"',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_5',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20',
#   'dist__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"stderr"',
#   'dist__absolute_sum_of_changes',
#   'dist__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.4',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_5',
#   'dist__linear_trend__attr_"stderr"',
#   'speed__large_standard_deviation__r_0.35000000000000003',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#   'speed__fft_coefficient__coeff_0__attr_"abs"',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_2',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5',
#   'speed__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_20',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#   'dist__has_duplicate_max',
#   'speed__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_5',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#   'dist__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#   'speed__friedrich_coefficients__m_3__r_30__coeff_2',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#   'dist__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue"',
#   'speed__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#   'speed__symmetry_looking__r_0.2',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#   'speed__symmetry_looking__r_0.05',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"slope"',
#   'speed__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.2',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept"',
#   'dist__minimum',
#   'speed__large_standard_deviation__r_0.1',
#   'dist__linear_trend__attr_"intercept"',
#   'speed__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"',
#   'speed__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"',
#   'dist__large_standard_deviation__r_0.1',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"stderr"',
#   'speed__linear_trend__attr_"intercept"',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#   'dist__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"',
#   'speed__linear_trend__attr_"slope"',
#   'dist__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"',
#   'dist__cid_ce__normalize_False',
#   'dist__max_langevin_fixed_point__m_3__r_30',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_1',
#   'dist__symmetry_looking__r_0.05',
#   'speed__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue"',
#   'dist__linear_trend__attr_"slope"',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.2',
#   'speed__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#   'dist__friedrich_coefficients__m_3__r_30__coeff_0',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#   'dist__number_peaks__n_50',
#   'speed__large_standard_deviation__r_0.2',
#   'speed__symmetry_looking__r_0.15000000000000002',
#   'dist__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#   'dist__large_standard_deviation__r_0.2',
#   'dist__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#   'dist__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#   'dist__large_standard_deviation__r_0.25',
#   'speed__large_standard_deviation__r_0.30000000000000004',
#   'speed__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#   'dist__symmetry_looking__r_0.1',
#   'speed__large_standard_deviation__r_0.65',
#   'speed__large_standard_deviation__r_0.6000000000000001',
#   'speed__large_standard_deviation__r_0.55',
#   'speed__large_standard_deviation__r_0.5',
#   'speed__large_standard_deviation__r_0.45',
#   'speed__large_standard_deviation__r_0.25',
#   'dist__large_standard_deviation__r_0.05',
#   'dist__large_standard_deviation__r_0.15000000000000002',
#   'dist__large_standard_deviation__r_0.30000000000000004',
#   'dist__sum_values',
#   'dist__symmetry_looking__r_0.0',
#   'dist__symmetry_looking__r_0.45',
#   'dist__symmetry_looking__r_0.9',
#   'dist__symmetry_looking__r_0.25',
#   'dist__symmetry_looking__r_0.30000000000000004',
#   'dist__symmetry_looking__r_0.35000000000000003',
#   'dist__symmetry_looking__r_0.4',
#   'speed__large_standard_deviation__r_0.7000000000000001',
#   'dist__symmetry_looking__r_0.5',
#   'dist__symmetry_looking__r_0.55',
#   'dist__symmetry_looking__r_0.6000000000000001',
#   'dist__symmetry_looking__r_0.65',
#   'dist__symmetry_looking__r_0.7000000000000001',
#   'dist__symmetry_looking__r_0.2',
#   'speed__large_standard_deviation__r_0.75',
#   'speed__minimum',
#   'speed__large_standard_deviation__r_0.8500000000000001',
#   'speed__has_duplicate_max',
#   'speed__has_duplicate',
#   'dist__symmetry_looking__r_0.8',
#   'dist__fft_coefficient__coeff_0__attr_"angle"',
#   'dist__fft_coefficient__coeff_0__attr_"imag"',
#   'dist__fft_coefficient__coeff_0__attr_"real"',
#   'speed__autocorrelation__lag_0',
#   'dist__variance_larger_than_standard_deviation',
#   'dist__variance',
#   'dist__value_count__value_1',
#   'dist__value_count__value_0',
#   'speed__large_standard_deviation__r_0.8',
#   'dist__value_count__value_-1',
#   'dist__has_duplicate',
#   'speed__large_standard_deviation__r_0.05',
#   'dist__has_duplicate_min',
#   'speed__large_standard_deviation__r_0.15000000000000002',
#   'speed__large_standard_deviation__r_0.4',
#   'speed__number_crossing_m__m_-1',
#   'dist__symmetry_looking__r_0.75',
#   'speed__mean_abs_change',
#   'speed__length',
#   'speed__large_standard_deviation__r_0.9500000000000001',
#   'speed__large_standard_deviation__r_0.9',
#   'dist__symmetry_looking__r_0.9500000000000001',
#   'dist__range_count__max_1000000000000.0__min_0',
#   'speed__range_count__max_1__min_-1',
#   'dist__partial_autocorrelation__lag_1',
#   'speed__symmetry_looking__r_0.4',
#   'speed__symmetry_looking__r_0.35000000000000003',
#   'speed__symmetry_looking__r_0.30000000000000004',
#   'speed__symmetry_looking__r_0.25',
#   'speed__symmetry_looking__r_0.0',
#   'speed__sum_values',
#   'speed__fft_coefficient__coeff_0__attr_"imag"',
#   'speed__range_count__max_0__min_1000000000000.0',
#   'speed__range_count__max_1000000000000.0__min_0',
#   'speed__has_duplicate_min',
#   'speed__partial_autocorrelation__lag_1',
#   'speed__symmetry_looking__r_0.8',
#   'dist__autocorrelation__lag_0',
#   'speed__partial_autocorrelation__lag_0',
#   'speed__variance',
#   'speed__value_count__value_1',
#   'speed__value_count__value_0',
#   'speed__value_count__value_-1',
#   'speed__symmetry_looking__r_0.9500000000000001',
#   'speed__symmetry_looking__r_0.9',
#   'speed__symmetry_looking__r_0.8500000000000001',
#   'speed__fft_coefficient__coeff_0__attr_"real"',
#   'dist__symmetry_looking__r_0.15000000000000002',
#   'speed__symmetry_looking__r_0.45',
#   'speed__symmetry_looking__r_0.5',
#   'speed__symmetry_looking__r_0.55',
#   'speed__symmetry_looking__r_0.6000000000000001',
#   'dist__partial_autocorrelation__lag_0',
#   'dist__large_standard_deviation__r_0.35000000000000003',
#   'dist__large_standard_deviation__r_0.4',
#   'dist__large_standard_deviation__r_0.45',
#   'dist__large_standard_deviation__r_0.5',
#   'dist__large_standard_deviation__r_0.55',
#   'dist__large_standard_deviation__r_0.6000000000000001',
#   'dist__large_standard_deviation__r_0.65',
#   'speed__number_crossing_m__m_0',
#   'dist__large_standard_deviation__r_0.7000000000000001',
#   'dist__large_standard_deviation__r_0.8',
#   'dist__range_count__max_0__min_1000000000000.0',
#   'dist__large_standard_deviation__r_0.8500000000000001',
#   'dist__large_standard_deviation__r_0.9500000000000001',
#   'dist__mean_abs_change',
#   'dist__number_crossing_m__m_-1',
#   'dist__number_crossing_m__m_1',
#   'dist__large_standard_deviation__r_0.75',
#   'speed__number_crossing_m__m_1',
#   'dist__symmetry_looking__r_0.8500000000000001',
#   'speed__fft_coefficient__coeff_0__attr_"angle"',
#   'speed__symmetry_looking__r_0.75',
#   'speed__symmetry_looking__r_0.7000000000000001',
#   'speed__symmetry_looking__r_0.65',
#   'dist__large_standard_deviation__r_0.9',
#   'speed__variance_larger_than_standard_deviation']}

# %%
fs.remove(methods = ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'])
# Out:
# Removed 672 features.
#       dist__abs_energy  dist__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 0         8.502048e+07                                           0.154229
# 1         3.615321e+08                                           0.477598
# 2         6.662529e+05                                           0.018031
# 3         2.990019e+08                                           0.344827
# 4         3.185586e+08                                          -0.000178
# ...                ...                                                ...
# 6995      8.883228e+08                                           0.305008
# 6996      5.613266e+08                                           0.019762
# 6997      3.780000e+08                                           0.218592
# 6998      3.170230e+08                                           0.494707
# 6999      2.952875e+08                                           0.459217
#
#       dist__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# 0                                              0.067793
# 1                                              0.035973
# 2                                              0.004836
# 3                                              0.051397
# 4                                              0.052468
# ...                                                 ...
# 6995                                           0.060839
# 6996                                           0.013272
# 6997                                           0.032468
# 6998                                           0.005041
# 6999                                           0.076243
#
#       dist__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# 0                                              0.379570
# 1                                              0.571745
# 2                                             -0.226858
# 3                                             -0.160105
# 4                                              0.028286
# ...                                                 ...
# 6995                                           0.276469
# 6996                                          -0.088875
# 6997                                          -0.357971
# 6998                                           0.618470
# 6999                                          -0.591254
#
#       dist__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# 0                                             26.125016
# 1                                             67.073959
# 2                                             -4.311280
# 3                                            -17.798107
# 4                                              3.315642
# ...                                                 ...
# 6995                                          53.874488
# 6996                                          -8.265576
# 6997                                         -64.683701
# 6998                                          83.063162
# 6999                                         -46.851466
#
#       dist__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"rvalue"  \
# 0                                              0.676204
# 1                                              0.609963
# 2                                             -0.715490
# 3                                             -0.329337
# 4                                             -0.372198
# ...                                                 ...
# 6995                                           0.075905
# 6996                                          -0.357014
# 6997                                          -0.592879
# 6998                                           0.520709
# 6999                                          -0.653800
#
#       dist__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr"  \
# 0                                            175.105245
# 1                                            276.138520
# 2                                             57.095436
# 3                                            325.242906
# 4                                            191.368991
# ...                                                 ...
# 6995                                         407.396019
# 6996                                         210.413320
# 6997                                         493.832332
# 6998                                         329.470098
# 6999                                         115.671000
#
#       dist__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue"  \
# 0                                              0.639512
# 1                                              0.738509
# 2                                             -0.472466
# 3                                             -0.174147
# 4                                              0.071064
# ...                                                 ...
# 6995                                           0.365710
# 6996                                          -0.465123
# 6997                                          -0.519323
# 6998                                           0.801398
# 6999                                          -0.560039
#
#       dist__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr"  \
# 0                                             55.032681
# 1                                             83.063237
# 2                                              2.977608
# 3                                            143.515528
# 4                                             47.281040
# ...                                                 ...
# 6995                                         172.688433
# 6996                                          25.008031
# 6997                                          95.246307
# 6998                                          77.119980
# 6999                                          80.418554
#
#       dist__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"intercept"  \
# 0                                            -74.973825
# 1                                           -227.852358
# 2                                              0.000000
# 3                                            375.962124
# 4                                             18.595279
# ...                                                 ...
# 6995                                         313.404543
# 6996                                         651.532537
# 6997                                          99.155986
# 6998                                        -126.391098
# 6999                                         525.300248
#
#       ...  speed__ratio_beyond_r_sigma__r_3  speed__ratio_beyond_r_sigma__r_5  \
# 0     ...                          0.026764                          0.021898
# 1     ...                          0.036649                          0.000000
# 2     ...                          0.004348                          0.004348
# 3     ...                          0.027108                          0.000000
# 4     ...                          0.040201                          0.000000
# ...   ...                               ...                               ...
# 6995  ...                          0.000000                          0.000000
# 6996  ...                          0.036842                          0.002632
# 6997  ...                          0.038585                          0.000000
# 6998  ...                          0.006231                          0.000000
# 6999  ...                          0.062802                          0.000000
#
#       speed__ratio_beyond_r_sigma__r_6  speed__ratio_beyond_r_sigma__r_7  \
# 0                             0.014599                          0.002433
# 1                             0.000000                          0.000000
# 2                             0.004348                          0.004348
# 3                             0.000000                          0.000000
# 4                             0.000000                          0.000000
# ...                                ...                               ...
# 6995                          0.000000                          0.000000
# 6996                          0.000000                          0.000000
# 6997                          0.000000                          0.000000
# 6998                          0.000000                          0.000000
# 6999                          0.000000                          0.000000
#
#       speed__sample_entropy  speed__skewness  \
# 0                  0.099516         5.643435
# 1                  0.771483         1.730982
# 2                  0.246190         8.982205
# 3                  0.630813         1.986827
# 4                  0.643937         2.198007
# ...                     ...              ...
# 6995               1.267992         0.920439
# 6996               1.751236         1.931891
# 6997               0.646043         2.043544
# 6998               1.235688         0.696609
# 6999               0.231259         3.079792
#
#       speed__spkt_welch_density__coeff_2  \
# 0                           4.798438e+02
# 1                           1.272873e+05
# 2                           2.280769e+05
# 3                           6.372508e+08
# 4                           2.287240e+08
# ...                                  ...
# 6995                        2.945048e+09
# 6996                        6.390505e+07
# 6997                        1.448885e+08
# 6998                        6.532409e+08
# 6999                        4.488582e+07
#
#       speed__sum_of_reoccurring_data_points  \
# 0                                  0.000000
# 1                               3055.209780
# 2                               2410.673574
# 3                              17315.462853
# 4                               1675.704583
# ...                                     ...
# 6995                            3613.147784
# 6996                               0.000000
# 6997                           10807.516891
# 6998                            3095.287624
# 6999                            3931.543558
#
#       speed__time_reversal_asymmetry_statistic__lag_2  \
# 0                                       -1.083863e+09
# 1                                        1.129006e+09
# 2                                        6.067487e+05
# 3                                       -2.132749e+09
# 4                                        1.278099e+10
# ...                                               ...
# 6995                                    -7.555274e+09
# 6996                                    -7.419109e+09
# 6997                                    -5.359380e+09
# 6998                                     1.803980e+08
# 6999                                    -1.656503e+08
#
#       speed__time_reversal_asymmetry_statistic__lag_3
# 0                                       -3.991336e+09
# 1                                        4.847130e+08
# 2                                        6.401649e+05
# 3                                       -1.027519e+09
# 4                                        1.709082e+10
# ...                                               ...
# 6995                                    -1.762101e+10
# 6996                                    -9.757936e+09
# 6997                                    -1.368612e+10
# 6998                                    -3.712039e+09
# 6999                                    -1.547984e+09
#
# [7000 rows x 836 columns]

# %%
train_new_df = fs.remove(methods = ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'])
test_new_df = test_df[train_new_df.columns]
# Out:
# Removed 672 features.

# %%
train_new_df.shape, test_new_df.shape
# Out:
# ((7000, 836), (2000, 836))

# %%
train_new_df.to_csv('train_preprocess_v1.csv', index=False)
test_new_df.to_csv('testB_preprocess_v1.csv', index=False)
