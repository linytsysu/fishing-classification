# %%
import pandas as pd

# %%
result1 = pd.read_csv('../history/result.csv', header=None, index_col=0)[1].values
# result2 = pd.read_csv('./result1.csv', header=None, index_col=0)[1].values
# result3 = pd.read_csv('./result2.csv', header=None, index_col=0)[1].values
result4 = pd.read_csv('./result.csv', header=None, index_col=0)[1].values

# %%
count = 0
for i in range(2000):
    if not(result1[i] == result4[i]):
        count += 1
        print(i, result1[i], result4[i])
print(count)
# Out:
# 9 拖网 围网
# 24 拖网 围网
# 28 拖网 围网
# 29 刺网 围网
# 33 拖网 刺网
# 43 拖网 刺网
# 45 拖网 刺网
# 58 拖网 围网
# 65 围网 刺网
# 67 拖网 围网
# 70 围网 刺网
# 73 围网 拖网
# 112 拖网 围网
# 133 拖网 围网
# 139 拖网 围网
# 158 拖网 刺网
# 170 围网 刺网
# 171 拖网 围网
# 183 拖网 围网
# 189 拖网 围网
# 198 刺网 拖网
# 201 拖网 刺网
# 217 围网 拖网
# 219 拖网 围网
# 221 刺网 围网
# 223 刺网 围网
# 231 拖网 围网
# 244 拖网 围网
# 247 拖网 围网
# 261 拖网 围网
# 270 围网 刺网
# 282 拖网 围网
# 295 刺网 拖网
# 309 拖网 刺网
# 317 围网 拖网
# 319 拖网 围网
# 323 围网 刺网
# 354 围网 刺网
# 402 拖网 刺网
# 411 拖网 围网
# 417 围网 刺网
# 425 围网 拖网
# 461 围网 拖网
# 477 刺网 围网
# 480 围网 拖网
# 486 围网 拖网
# 501 拖网 围网
# 516 拖网 围网
# 521 刺网 围网
# 530 拖网 刺网
# 540 刺网 拖网
# 544 围网 拖网
# 550 拖网 刺网
# 578 拖网 刺网
# 593 刺网 围网
# 594 围网 刺网
# 610 围网 刺网
# 618 刺网 围网
# 648 拖网 围网
# 661 围网 拖网
# 665 围网 拖网
# 671 围网 拖网
# 672 围网 拖网
# 676 围网 拖网
# 691 围网 拖网
# 708 围网 刺网
# 732 刺网 围网
# 733 围网 拖网
# 742 拖网 围网
# 792 围网 拖网
# 798 拖网 刺网
# 800 拖网 刺网
# 805 拖网 刺网
# 809 拖网 刺网
# 817 围网 拖网
# 825 围网 拖网
# 829 围网 刺网
# 891 围网 拖网
# 896 刺网 围网
# 899 拖网 刺网
# 911 围网 拖网
# 928 刺网 拖网
# 949 围网 刺网
# 962 围网 拖网
# ...
