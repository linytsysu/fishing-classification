# %%
import os
import pandas as pd
import numpy as np

# %%
train_path = '../data/hy_round1_train_20200102'
test_path = '../data/hy_round1_testA_20200102'

train_df_list = []
for file_name in os.listdir(train_path):
    df = pd.read_csv(os.path.join(train_path, file_name))
    train_df_list.append(df)
    
test_df_list = []
for file_name in os.listdir(test_path):
    df = pd.read_csv(os.path.join(test_path, file_name))
    test_df_list.append(df)

train_df = pd.concat(train_df_list)
test_df = pd.concat(test_df_list)

train_df['time'] = pd.to_datetime(train_df['time'], format='%m%d %H:%M:%S')
test_df['time'] = pd.to_datetime(test_df['time'], format='%m%d %H:%M:%S')

all_df = pd.concat([train_df, test_df], sort=False)

# %%
df = all_df.drop(columns=['type'])
y = all_df['type']

# %%
from tsfresh import extract_features
extracted_df = extract_features(df, column_id='渔船ID', column_sort='time')
# Out:
# Feature Extraction: 100%|██████████| 30/30 [56:54<00:00, 113.80s/it]

# %%
train_df = extracted_df.iloc[:7000]
test_df = extracted_df.iloc[7000:]

# %%
train_df.to_csv('train_temp.csv', index=False)
test_df.to_csv('test_temp.csv', index=False)

train_df = pd.read_csv('train_temp.csv')
test_df = pd.read_csv('test_temp.csv')

# %%
from feature_selector import FeatureSelector

# %%
y = []
for name, group in all_df.groupby('渔船ID'):
    y.append(group.iloc[0]['type'])

y_train = y[:7000]
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y_train = le.fit_transform(y_train)

# %%
fs = FeatureSelector(data=train_df, labels=y_train)

# %%
fs.identify_missing(missing_threshold=0.6)
# Out:
# 20 features with greater than 0.60 missing values.

# %%
fs.identify_single_unique()
# Out:
# 51 features with a single unique value.

# %%
fs.identify_collinear(correlation_threshold=0.96)
# Out:
# 732 features with a correlation magnitude greater than 0.96.

# %%
fs.identify_zero_importance(task='classification', eval_metric='multi_logloss', 
                            n_iterations=10, early_stopping=True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [236]	valid_0's multi_logloss: 0.28863
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [318]	valid_0's multi_logloss: 0.236665
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [195]	valid_0's multi_logloss: 0.294681
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [197]	valid_0's multi_logloss: 0.314341
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [149]	valid_0's multi_logloss: 0.339961
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [250]	valid_0's multi_logloss: 0.292286
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [198]	valid_0's multi_logloss: 0.316347
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [182]	valid_0's multi_logloss: 0.311018
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [283]	valid_0's multi_logloss: 0.26129
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [223]	valid_0's multi_logloss: 0.297567
#
# 217 features with zero importance after one-hot encoding.

# %%
fs.identify_low_importance(cumulative_importance=0.96)
# Out:
# 2152 features required for cumulative importance of 0.96 after one hot encoding.
# 864 features do not contribute to cumulative importance of 0.96.

# %%
fs.remove(methods = ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'])
# Out:
# Removed 1264 features.
#       x__abs_energy  x__absolute_sum_of_changes  \
agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"stderr"  ...  \
# 0                                             64.322082              ...
# 1                                            158.568694              ...
# 2                                              5.314295              ...
# 3                                            277.702500              ...
# 4                                             78.266891              ...
# ...                                                 ...              ...
# 6995                                         388.730315              ...
# 6996                                         186.796668              ...
# 6997                                         310.713540              ...
# 6998                                         103.183571              ...
# 6999                                          71.736731              ...
#
#       速度__spkt_welch_density__coeff_5  速度__spkt_welch_density__coeff_8  \
# 0                            0.006591                         0.005671
# 1                          124.460879                        59.702687
# 2                           75.081499                        32.177442
# 3                           59.834443                        23.925398
# 4                          135.702669                        21.729297
# ...                               ...                              ...
# 6995                       265.160642                        29.926829
# 6996                        27.829023                        48.768572
# 6997                        19.618620                        17.796027
# 6998                        15.503903                        13.991880
# 6999                         3.900611                         4.069615
#
#       速度__standard_deviation  速度__sum_of_reoccurring_values  \
# 0                   1.319651                          14.83
# 1                   2.409553                         109.98
# 2                   3.408486                           5.02
# 3                   2.524816                         108.78
# 4                   2.493721                         123.75
# ...                      ...                            ...
# 6995                2.797322                         181.67
# 6996                1.349902                         110.06
# 6997                2.466203                          93.52
# 6998                2.030258                         112.48
# 6999                2.455101                          34.10
#
#       速度__symmetry_looking__r_0.05  速度__symmetry_looking__r_0.1  \
# 0                              1.0                          1.0
# 1                              0.0                          0.0
# 2                              1.0                          1.0
# 3                              0.0                          0.0
# 4                              0.0                          0.0
# ...                            ...                          ...
# 6995                           1.0                          1.0
# 6996                           1.0                          1.0
# 6997                           0.0                          0.0
# 6998                           0.0                          1.0
# 6999                           0.0                          1.0
#
#       速度__time_reversal_asymmetry_statistic__lag_1  \
# 0                                         0.091496
# 1                                         0.111732
# 2                                        -5.297964
# 3                                        -0.302473
# 4                                        -0.985539
# ...                                            ...
# 6995                                     -0.408664
# 6996                                     -0.784376
# 6997                                     -0.682603
# 6998                                      0.295247
# 6999                                      0.264832
#
#       速度__time_reversal_asymmetry_statistic__lag_2  \
# 0                                        -0.248293
# 1                                        -0.019020
# 2                                         2.993956
# 3                                        -0.133740
# 4                                         1.144961
# ...                                            ...
# 6995                                     -1.130359
# 6996                                     -1.466676
# 6997                                     -0.603062
# 6998                                      0.242054
# 6999                                      0.056469
#
#       速度__time_reversal_asymmetry_statistic__lag_3  速度__value_count__value_0
# 0                                        -0.457245                     369.0
# 1                                        -0.132295                     131.0
# 2                                         0.578998                      54.0
# 3                                        -0.305196                      70.0
# 4                                         0.964508                      61.0
# ...                                            ...                       ...
# 6995                                     -2.039815                      30.0
# 6996                                     -1.557038                       0.0
# 6997                                     -0.939807                      65.0
# 6998                                     -0.410336                      28.0
# 6999                                     -0.174032                      86.0
#
# [7000 rows x 1752 columns]

# %%
train_new_df = fs.remove(methods = ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'])
test_new_df = test_df[train_new_df.columns]
# Out:
# Removed 1264 features.

# %%
train_new_df.to_csv('train_preprocess_v4.csv', index=False)
test_new_df.to_csv('test_preprocess_v4.csv', index=False)
