# %%
import os
import numpy as np
import pandas as pd
from tsfresh import select_features, extract_features
from tsfresh.utilities.dataframe_functions import impute
from sklearn import preprocessing

# %%
train_path = '../data/hy_round2_train_20200225'

def tsfresh_extract_features():
    train_df_list = []
    for file_name in os.listdir(train_path):
        df = pd.read_csv(os.path.join(train_path, file_name))
        train_df_list.append(df)

    train_df = pd.concat(train_df_list)

    train_df['time'] = pd.to_datetime(train_df['time'], format='%m%d %H:%M:%S')

    all_df = pd.concat([train_df], sort=False)

    df = all_df.drop(columns=['type'])

    extracted_df = extract_features(df, column_id='渔船ID', column_sort='time', n_jobs=8)

    train_df = extracted_df.iloc[:len(train_df_list)]

    y = []
    for name, group in all_df.groupby('渔船ID'):
        y.append(group.iloc[0]['type'])

    y_train = y[:train_df.shape[0]]
    le = preprocessing.LabelEncoder()
    y_train = le.fit_transform(y_train)

    impute(train_df)
    filtered_train_df = select_features(train_df, y_train)

    filtered_train_df['type'] = le.inverse_transform(y_train)

    if not os.path.exists('./feature'):
        os.makedirs('./feature')
    filtered_train_df.to_csv('./feature/train.csv')

    return filtered_train_df

# %%
tsfresh_extract_features()
# Out:
# Feature Extraction: 100%|██████████| 40/40 [1:54:04<00:00, 171.12s/it]
# WARNING:tsfresh.feature_selection.relevance:Infered classification as machine learning task
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__fft_coefficient__coeff_0__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__fft_coefficient__coeff_0__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__number_crossing_m__m_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__partial_autocorrelation__lag_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__range_count__max_0__min_1000000000000.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__has_duplicate is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__symmetry_looking__r_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__value_count__value_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lat__value_count__value_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__fft_coefficient__coeff_0__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__fft_coefficient__coeff_0__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__number_crossing_m__m_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__partial_autocorrelation__lag_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__range_count__max_0__min_1000000000000.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__has_duplicate is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__symmetry_looking__r_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__value_count__value_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature lon__value_count__value_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__fft_coefficient__coeff_0__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__fft_coefficient__coeff_0__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.55 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.6000000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.65 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.7000000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.75 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.8500000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.9 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__large_standard_deviation__r_0.9500000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__number_crossing_m__m_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__partial_autocorrelation__lag_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__has_duplicate is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__range_count__max_0__min_1000000000000.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__symmetry_looking__r_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 方向__value_count__value_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__fft_coefficient__coeff_0__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__fft_coefficient__coeff_0__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__number_crossing_m__m_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__partial_autocorrelation__lag_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__range_count__max_0__min_1000000000000.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__has_duplicate is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__symmetry_looking__r_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__value_count__value_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature 速度__value_count__value_1 is constant
# variable  lon__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2  \
# id
# 20000                                             15.041422
# 20001                                             15.555658
# 20002                                             15.646361
# 20003                                             15.329394
# 20004                                             15.548528
# ...                                                     ...
# 28161                                             15.537333
# 28162                                             15.499214
# 28163                                             15.269452
# 28164                                             15.329169
# 28165                                             15.686427
#
# variable  lat__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20  \
# id
# 20000                                             39.086500
# 20001                                             45.787256
# 20002                                             50.057259
# 20003                                             41.980946
# 20004                                             47.820621
# ...                                                     ...
# 28161                                             45.836438
# 28162                                             46.178734
# 28163                                             43.251405
# 28164                                             44.844764
# 28165                                             48.741158
#
# variable  lat__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5  \
# id
# 20000                                              8.002773
# 20001                                              9.413717
# 20002                                             10.321680
# 20003                                              8.657685
# 20004                                              9.861144
# ...                                                     ...
# 28161                                              9.488184
# 28162                                              9.521201
# 28163                                              8.918322
# 28164                                              9.246412
# 28165                                             10.026654
#
# variable  lat__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_10  \
# id
# 20000                                             33.991337
# 20001                                             40.046062
# 20002                                             43.744373
# 20003                                             36.675710
# 20004                                             41.790447
# ...                                                     ...
# 28161                                             40.122831
# 28162                                             40.354675
# 28163                                             37.796860
# 28164                                             39.188411
# 28165                                             42.402143
#
# variable  lon__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5  \
# id
# 20000                                             30.066673
# 20001                                             31.086398
# 20002                                             31.281147
# 20003                                             30.493956
# 20004                                             31.085651
# ...                                                     ...
# 28161                                             30.959063
# 28162                                             30.986109
# 28163                                             30.527607
# 28164                                             30.646730
# 28165                                             31.415897
#
# variable  lat__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20  \
# id
# 20000                                             41.396290
# 20001                                             48.561202
# 20002                                             53.059871
# 20003                                             44.500222
# 20004                                             50.689021
# ...                                                     ...
# 28161                                             48.587373
# 28162                                             48.948737
# 28163                                             45.845767
# 28164                                             47.534671
# 28165                                             51.667437
#
# variable  lat__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5  \
# id
# 20000                                              5.494960
# 20001                                              6.479546
# 20002                                              7.097635
# 20003                                              5.955826
# 20004                                              6.781237
# ...                                                     ...
# 28161                                              6.481232
# 28162                                              6.546866
# 28163                                              6.132625
# 28164                                              6.358182
# 28165                                              6.943112
#
# variable  lat__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_10  \
# id
# 20000                                             32.484090
# 20001                                             38.317047
# 20002                                             41.816981
# 20003                                             35.060232
# 20004                                             39.949011
# ...                                                     ...
# 28161                                             38.302420
# 28162                                             38.576620
# 28163                                             36.131530
# 28164                                             37.461899
# 28165                                             40.569163
#
# variable  lat__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20  \
# id
# 20000                                             43.433685
# 20001                                             51.014413
# 20002                                             55.712556
# 20003                                             46.726224
# 20004                                             53.223129
# ...                                                     ...
# 28161                                             51.017661
# 28162                                             51.395931
# 28163                                             48.137779
# 28164                                             49.911088
# 28165                                             54.254827
#
# variable  lat__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5  ...  \
# id                                                                     ...
# 20000                                              3.595712            ...
# 20001                                              4.263204            ...
# 20002                                              4.656219            ...
# 20003                                              3.909379            ...
# 20004                                              4.448959            ...
# ...                                                     ...            ...
# 28161                                              4.196428            ...
# 28162                                              4.294614            ...
# 28163                                              4.023149            ...
# 28164                                              4.171075            ...
# 28165                                              4.611481            ...
#
# variable  速度__fft_coefficient__coeff_79__attr_"abs"  \
# id
# 20000                                     22.843813
# 20001                                     60.723283
# 20002                                      1.624750
# 20003                                     14.019591
# 20004                                      4.533309
# ...                                             ...
# 28161                                     30.932981
# 28162                                      9.487354
# 28163                                     16.192627
# 28164                                     36.856627
# 28165                                     37.404456
#
# variable  lon__number_cwt_peaks__n_5  \
# id
# 20000                           45.0
# 20001                           40.0
# 20002                            6.0
# 20003                           47.0
# 20004                           22.0
# ...                              ...
# 28161                           28.0
# 28162                           30.0
# 28163                           42.0
# 28164                           23.0
# 28165                           38.0
#
# variable  速度__fft_coefficient__coeff_82__attr_"abs"  \
# id
# 20000                                     19.766003
# 20001                                     14.144836
# 20002                                      3.165306
# 20003                                     35.499179
# 20004                                     16.310496
# ...                                             ...
# 28161                                    102.915530
# 28162                                     59.414658
# 28163                                     40.618786
# 28164                                     46.997504
# 28165                                     16.770440
#
# variable  速度__fft_coefficient__coeff_74__attr_"abs"  \
# id
# 20000                                     73.241138
# 20001                                     39.208915
# 20002                                      2.712678
# 20003                                     14.815519
# 20004                                      7.121245
# ...                                             ...
# 28161                                     40.110297
# 28162                                     61.754050
# 28163                                     19.006193
# 28164                                     46.051485
# 28165                                     30.006633
#
# variable  方向__fft_coefficient__coeff_5__attr_"imag"  \
# id
# 20000                                   -992.511057
# 20001                                   -832.201707
# 20002                                    -76.997668
# 20003                                   4992.039880
# 20004                                   -820.528246
# ...                                             ...
# 28161                                   1567.237664
# 28162                                   3026.158089
# 28163                                  -5919.693946
# 28164                                   -891.505956
# 28165                                  -6196.184360
#
# variable  速度__fft_coefficient__coeff_87__attr_"abs"  \
# id
# 20000                                     26.937354
# 20001                                     10.420878
# 20002                                      1.789029
# 20003                                     41.621580
# 20004                                      6.919305
# ...                                             ...
# 28161                                     31.425718
# 28162                                     42.029938
# 28163                                      8.946803
# 28164                                     22.292978
# 28165                                     31.478121
#
# variable  速度__fft_coefficient__coeff_73__attr_"abs"  \
# id
# 20000                                     62.719212
# 20001                                     42.154673
# 20002                                      1.697228
# 20003                                     36.930767
# 20004                                      3.913123
# ...                                             ...
# 28161                                     40.045110
# 28162                                     47.234707
# 28163                                      5.202907
# 28164                                     12.777289
# 28165                                     20.223974
#
# variable  方向__fft_coefficient__coeff_20__attr_"real"  \
# id
# 20000                                    6708.335041
# 20001                                    7686.128966
# 20002                                    -626.520463
# 20003                                     528.637311
# 20004                                   -1242.016415
# ...                                              ...
# 28161                                    1669.260586
# 28162                                    -678.640743
# 28163                                    2847.785713
# 28164                                    -423.592220
# 28165                                    1365.140275
#
# variable  lat__symmetry_looking__r_0.35000000000000003  type
# id
# 20000                                              1.0    拖网
# 20001                                              1.0    围网
# 20002                                              1.0    刺网
# 20003                                              1.0    拖网
# 20004                                              1.0    刺网
# ...                                                ...   ...
# 28161                                              1.0    围网
# 28162                                              1.0    围网
# 28163                                              1.0    拖网
# 28164                                              1.0    刺网
# 28165                                              1.0    围网
#
# [8166 rows x 1568 columns]
